# %%
#work flow of ml
#data ingestion data cleaning and processing  data ml model
#model trainig  model prediction   calculate model performance

# %%
#data cleaning and processing
#data  x_train,x_test,y_train,y_test
#machine(x_train,y_train)
#1+2=3
#2+2=4
#3=2=5
#machine (5+7)predict =13
#5+7=x_test
#12=y_test
#13=y_pred
#machine(y_pred ,y_test)

# %%
#how can create data devision

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/covid_toy - covid_toy.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever']=df['fever'].fillna(df['fever'].mean())

# %%
x=df.drop(columns=['has_covid']) #input or independent data
x.shape
# Out:
# (100, 5)

# %%
y=df['has_covid'] #target or dependent data
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,
                                               y,
                                               test_size=0.2,
                                               random_state=42)

# %%
print("total data shape",df.shape)
print("----------------")
print("input data shape",x.shape)
print("x_train data shape",x_train.shape)
print("x_test data shape",x_test.shape)
print("----------------")
print("target data shape",y.shape)
print("y_train data shape",y_train.shape)
print("y_test data shape",y_test.shape)
print("----------------")
# Out:
# total data shape (100, 6)
# ----------------
# input data shape (100, 5)
# x_train data shape (80, 5)
# x_test data shape (20, 5)
# ----------------
# target data shape (100,)
# y_train data shape (80,)
# y_test data shape (20,)
# ----------------

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Customer_Call.xlsx - Call List.csv")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            1
# Phone_Number         2
# Address              0
# Paying Customer      0
# Do_Not_Contact       4
# Not_Useful_Column    0
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 7         1008   Sherlock       Holmes  876|678|3469
# 9         1010      Peter       Parker  123-545-5421
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# 18        1019      Creed       Braton           N/a
# 19        1020     Anakin    Skywalker  876|678|3469
# 20        1020     Anakin    Skywalker  876|678|3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            0
# Phone_Number         0
# Address              0
# Paying Customer      0
# Do_Not_Contact       0
# Not_Useful_Column    0
# dtype: int64

# %%
df.shape
# Out:
# (15, 8)

# %%
x=df.drop(columns=['Paying Customer'])
x.shape
# Out:
# (15, 7)

# %%
y=df['Paying Customer']
y.shape
# Out:
# (15,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,
                                               y,
                                               test_size=0.2,
                                               random_state=42)

# %%
print("Total data shape:",df.shape)
print("----------------")
print("Input data shape:",x.shape)
print("x_train data shape:",x_train.shape)
print("x_test data shape:",x_test.shape)
print("----------------")
print("Target data shape:",y.shape)
print("y_train data shape:",y_train.shape)
print("y_test data shape:",y_test.shape)
print("----------------")
# Out:
# Total data shape: (15, 8)
# ----------------
# Input data shape: (15, 7)
# x_train data shape: (12, 7)
# x_test data shape: (3, 7)
# ----------------
# Target data shape: (15,)
# y_train data shape: (12,)
# y_test data shape: (3,)
# ----------------

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/titanic - titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
df=df['Cabin'].value_counts()
df
# Out:
# Cabin
# B57 B59 B63 B66    3
# B45                2
# C23 C25 C27        2
# C78                2
# C31                2
#                   ..
# B41                1
# C7                 1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 76, dtype: int64

# %%
df=df.drop(columns=['cabin'])

# %%
df.shape
# Out:
# (76,)

# %%
x=df.drop(columns=['Survived	Pclass'])
x.shape
# Out:
# (76,)

# %%
y=df['Survived	Pclass']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Survived\tPclass'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-353621749.py in <cell line: 0>()
# ----> 1 y=df['Survived  Pclass']
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,
                                               y,
                                               test_size=0.2,
                                               random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3208377099.py in <cell line: 0>()
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,
#       2                                                y,
#       3                                                test_size=0.2,
#       4                                                random_state=42)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# ...

# %%
print("Total data shape:",df.shape)
print("----------------")
print("Input data shape:",x.shape)
print("x_train data shape:",x_train.shape)
print("x_test data shape:",x_test.shape)
print("----------------")
print("Target data shape:",y.shape)
print("y_train data shape:",y_train.shape)
print("y_test data shape:",y_test.shape)
print("----------------")
# Out:
# Total data shape: (76,)
# ----------------
# Input data shape: (76,)
# x_train data shape: (72, 3)
# x_test data shape: (18, 3)
# ----------------
# Target data shape: (90,)
# y_train data shape: (72,)
# y_test data shape: (18,)
# ----------------
