# %%
#Decision tree

# %%
import numpy as np
import pandas as pd

# %%
di=pd.read_csv("/content/insurance - insurance.csv")

# %%
di
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
x=di.drop(columns=['charges'])
y=di['charges']

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
x['sex']=lb.fit_transform(x['sex'])
x['smoker']=lb.fit_transform(x['smoker'])
x['region']=lb.fit_transform(x['region'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7290139487263241

# %%
dc=pd.read_csv("/content/covid_toy - covid_toy.csv")

# %%
dc
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
dc['fever']=dc['fever'].fillna(dc['fever'].mean())

# %%
x=dc.drop(columns=['has_covid'])
y=dc['has_covid']

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
x['gender']=lb.fit_transform(x['gender'])
x['city']=lb.fit_transform(x['city'])
x['cough']=lb.fit_transform(x['cough'])

# %%
dc
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
#dc.dtypes

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.45

# %%
df=pd.read_csv("/content/Churn_Modelling - Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#df.isnull().sum()

# %%
df=df.drop(columns=['Surname'])

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
df['Gender']=lb.fit_transform(df['Gender'])
df['Geography']=lb.fit_transform(df['Geography'])

# %%
x=df.drop(columns=['Exited'])
y=df['Exited']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7865

# %%
da=pd.read_csv("/content/cars - cars.csv")

# %%
da
# Out:
#                                         name  year  selling_price  km_driven  \
# 0                         Maruti 800 AC BSII  1992          50000     100000
# 1                   Maruti Gypsy E MG410W ST  1995          95000     100000
# 2                   Mahindra Jeep CL 500 MDI  1996         250000      35000
# 3                       Mahindra Jeep MM 540  1996         200000      60000
# 4                   Mahindra Jeep CL 500 MDI  1997         150000     120000
# ...                                      ...   ...            ...        ...
# 4335         Hyundai Venue SX Opt Turbo BSIV  2020        1050000       1100
# 4336  Hyundai Grand i10 1.2 Kappa Magna BSIV  2020         545000       5000
# 4337      Ford Figo Aspire 1.5 TDCi Titanium  2020         530000      45000
# 4338                         Tata Harrier XE  2020         426000       1000
# 4339               Honda Amaze S Petrol BSIV  2020         614000       1000
#
# ...

# %%
da=da.drop(columns=['name'])

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
da['fuel']=lb.fit_transform(da['fuel'])
da['seller_type']=lb.fit_transform(da['seller_type'])
da['transmission']=lb.fit_transform(da['transmission'])
da['owner']=lb.fit_transform(da['owner'])

# %%
x=da.drop(columns=['selling_price'])
y=da['selling_price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dt.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.5427428898332741
