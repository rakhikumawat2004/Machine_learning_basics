# %%
import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

from sklearn.preprocessing import OrdinalEncoder

# %%
df=pd.read_csv("/content/covid_toy - covid_toy.csv")

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(df.drop(
    columns=['has_covid']),df['has_covid'],test_size=0.2)

# %%
x_train
# Out:
#     age  gender  fever   cough       city
# 7    20  Female    NaN  Strong     Mumbai
# 35   82  Female  102.0  Strong  Bangalore
# 76   80    Male  100.0    Mild  Bangalore
# 85   16  Female  103.0    Mild  Bangalore
# 94   79    Male    NaN  Strong    Kolkata
# ..  ...     ...    ...     ...        ...
# 97   20  Female  101.0    Mild  Bangalore
# 95   12  Female  104.0    Mild  Bangalore
# 54   60  Female   99.0    Mild     Mumbai
# 31   83    Male  103.0    Mild    Kolkata
# 57   49  Female   99.0  Strong  Bangalore
#
# [80 rows x 5 columns]

# %% [markdown]
# Manually type output

# %%
#adding simple imputer to fever column
si=SimpleImputer(strategy="mean")
x_train_fever=si.fit_transform(x_train[['fever']])

#also the test data
x_test_fever=si.fit_transform(x_test[['fever']])

x_train_fever.shape
# Out:
# (80, 1)

# %%
#ordinal Encoding cough
oe=OrdinalEncoder(categories=[['Mild','Strong']])
x_train_cough=oe.fit_transform(x_train[['cough']])

#also the test data
x_test_cough=oe.fit_transform(x_test[['cough']])

x_train_cough.shape
# Out:
# (80, 1)

# %%
#onehotenoding  gender ,city
ohe=OneHotEncoder(drop='first',sparse_output=False)
x_train_gender_city=ohe.fit_transform(x_train[['gender','city']])

#also the test data
x_test_gender_city=ohe.fit_transform(x_test[['gender','city']])

x_train_gender_city.shape
# Out:
# (80, 4)

# %%
#extracting age
x_train_age=x_train.drop(columns=
                         ['gender','fever','cough','city']).values

#also the test data
x_test_age=x_test.drop(columns=
                         ['gender','fever','cough','city']).values

# %%
x_train_age.shape
# Out:
# (80, 1)

# %%
x_train_transformed=np.concatenate((x_train_age,x_train_fever,
                                    x_train_gender_city,
                                    x_train_cough),axis=1)

# %%
#x_test_transformed=np.concatenate((x_test_age,x_test_fever,
#                                    x_test_gender_city,
 #                                   x_test_cough),axis=1)

# %%
x_train_transformed.shape
# Out:
# (80, 7)

# %%
from sklearn.compose import ColumnTransformer
transformer=ColumnTransformer(transformers=[
    ('tnf1',SimpleImputer(),['fever']),
    ('tnf2',OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),
    ('tnf3',OneHotEncoder(sparse_output=False,drop='first'),['gender','city'])
],remainder='passthrough')

# %%
transformer.fit_transform(x_train).shape
# Out:
# (80, 7)

# %%
transformer.transform(x_test).shape
# Out:
# (20, 7)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(tips.drop(
    columns=['total_bill']),tips['total_bill'],test_size=0.2)

# %%
x_train
# Out:
#       tip     sex smoker   day    time  size
# 101  3.00  Female    Yes   Fri  Dinner     2
# 78   3.00    Male     No  Thur   Lunch     2
# 225  2.50  Female    Yes   Fri   Lunch     2
# 169  2.00  Female    Yes   Sat  Dinner     2
# 73   5.00  Female    Yes   Sat  Dinner     2
# ..    ...     ...    ...   ...     ...   ...
# 63   3.76    Male    Yes   Sat  Dinner     4
# 144  2.30  Female     No  Thur   Lunch     2
# 195  1.44    Male     No  Thur   Lunch     2
# 229  2.88  Female    Yes   Sat  Dinner     2
# 126  1.48    Male     No  Thur   Lunch     2
#
# [195 rows x 6 columns]

# %%
#ordinal Encoding cough
oe=OrdinalEncoder(categories=[['Yes','No']])
x_train_smoker=oe.fit_transform(x_train[['smoker']])

#also the test data
x_test_smoker=oe.transform(x_test[['smoker']])

x_train_smoker.shape
# Out:
# (195, 1)

# %%
#onehotenoding  sex,day
ohe=OneHotEncoder(drop='first',sparse_output=False)
x_train_sex_day_time=ohe.fit_transform(x_train[['sex','day','time']])

#also the test data
x_test_sex_day_time=ohe.fit_transform(x_test[['sex','day','time']])

x_train_sex_day_time.shape
# Out:
# (195, 5)

# %%
#extract size column
x_train_size=x_train[['size']].values

# %%
x_train_size.shape
# Out:
# (195, 1)

# %%
x_test_size=x_test[['size']].values

# %%
x_test_size.shape
# Out:
# (49, 1)

# %%
x_train_tip=x_train[['tip']].values

# %%
x_train_tip.shape
# Out:
# (195, 1)

# %%
x_test_tip=x_test[['tip']].values

# %%
x_test_tip.shape
# Out:
# (49, 1)

# %%
x_train_transformed=np.concatenate((x_train_smoker,x_train_sex_day_time,x_train_size,x_train_tip),axis=1)
x_train_transformed.shape
# Out:
# (195, 8)

# %%
x_test_transformed=np.concatenate((x_test_smoker,x_test_sex_day_time,x_test_tip),axis=1)
x_test_transformed.shape
# Out:
# (49, 7)

# %%
from sklearn.compose import ColumnTransformer
transformer=ColumnTransformer(transformers=[
    ('tnf1',OrdinalEncoder(categories=[['Yes','No']]),['smoker']),
    ('tnf2',OneHotEncoder(sparse_output=False,drop='first'),['sex','day','time']
     )],remainder='passthrough')

# %%
transformer.fit_transform(x_train).shape
# Out:
# (195, 8)

# %%
transformer.transform(x_test).shape
# Out:
# (49, 8)
