# %%
# logistic regression model
#this is classification model and when ourtarget data is categorical,then we can
#use this model.
#in backend,activation function(sigmoid)=>cnvert into propability(0-1)=>
#threshold_value=1/2 or 0.5
#if x>0.5
#return 1
#else
#return 0

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/covid_toy - covid_toy.csv")

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
#df.isnull().sum()

# %%
df['fever']=df['fever'].fillna(df['fever'].mean())

# %%
#df.isnull().sum()

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
df['gender']=lb.fit_transform(df['gender'])
df['cough']=lb.fit_transform(df['cough'])
df['city']=lb.fit_transform(df['city'])
df['has_covid']=lb.fit_transform(df['has_covid'])

# %%
df
# Out:
#     age  gender  fever  cough  city  has_covid
# 0    60       1  103.0      0     2          0
# 1    27       1  100.0      0     1          1
# 2    42       1  101.0      0     1          0
# 3    31       0   98.0      0     2          0
# 4    65       0  101.0      0     3          0
# ..  ...     ...    ...    ...   ...        ...
# 95   12       0  104.0      0     0          0
# 96   51       0  101.0      1     2          1
# 97   20       0  101.0      0     0          0
# 98    5       0   98.0      1     3          0
# 99   10       0   98.0      1     2          1
#
# [100 rows x 6 columns]

# %%
x=df.drop(columns=['has_covid'])
y=df['has_covid']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.75

# %%
ds=pd.read_csv("/content/titanic - titanic.csv")

# %%
ds
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
ds.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
ds['Age']=ds['Age'].fillna(ds['Age'].mean())

# %%
ds=ds.drop(columns=['Cabin','Name'])

# %%
ds
# Out:
#      PassengerId  Survived  Pclass     Sex       Age  SibSp  Parch  \
# 0            892         0       3    male  34.50000      0      0
# 1            893         1       3  female  47.00000      1      0
# 2            894         0       2    male  62.00000      0      0
# 3            895         0       3    male  27.00000      0      0
# 4            896         1       3  female  22.00000      1      1
# ..           ...       ...     ...     ...       ...    ...    ...
# 413         1305         0       3    male  30.27259      0      0
# 414         1306         1       1  female  39.00000      0      0
# 415         1307         0       3    male  38.50000      0      0
# 416         1308         0       3    male  30.27259      0      0
# 417         1309         0       3    male  30.27259      1      1
#
#                  Ticket      Fare Embarked
# 0                330911    7.8292        Q
# 1                363272    7.0000        S
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
ds['Sex']=lb.fit_transform(ds['Sex'])
ds['Ticket']=lb.fit_transform(ds['Ticket'])
ds['Embarked']=lb.fit_transform(ds['Embarked'])

# %%
ds
# Out:
#      PassengerId  Survived  Pclass  Sex       Age  SibSp  Parch  Ticket  \
# 0            892         0       3    1  34.50000      0      0     152
# 1            893         1       3    0  47.00000      1      0     221
# 2            894         0       2    1  62.00000      0      0      73
# 3            895         0       3    1  27.00000      0      0     147
# 4            896         1       3    0  22.00000      1      1     138
# ..           ...       ...     ...  ...       ...    ...    ...     ...
# 413         1305         0       3    1  30.27259      0      0     267
# 414         1306         1       1    0  39.00000      0      0     324
# 415         1307         0       3    1  38.50000      0      0     346
# 416         1308         0       3    1  30.27259      0      0     220
# 417         1309         0       3    1  30.27259      1      1     105
#
#          Fare  Embarked
# 0      7.8292         1
# 1      7.0000         2
# 2      9.6875         1
# ...

# %%
ds.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket           int64
# Fare           float64
# Embarked         int64
# dtype: object

# %%
ds.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %%
ds['Fare'] = ds['Fare'].fillna(ds['Fare'].mean())

# %%
x=ds.drop(columns=['Survived'])
y=ds['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
dr=pd.read_csv("/content/Churn_Modelling - Churn_Modelling.csv")

# %%
dr
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
dr.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
dr=dr.drop(columns=['Surname','Geography'])

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
dr['Gender']=lb.fit_transform(dr['Gender'])

# %%
x=dr.drop(columns=['Exited'])
y=dr['Exited']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8035

# %%
di=pd.read_csv("/content/insurance - insurance.csv")

# %%
di
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
di['sex']=lb.fit_transform(di['sex'])
di['smoker']=lb.fit_transform(di['smoker'])
di['region']=lb.fit_transform(di['region'])

# %%
x=di.drop(columns=['charges'])
y=di['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7833463107364539
