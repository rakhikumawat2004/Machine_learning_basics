# %%
#Introduction to pandas::
#install data scraper
#pandas is an open source library of python which is used for handle data manipulation

# %%
#!pip install pandas

# %%
import pandas as pd

# %%
#data structure of pandas
#(1) series
#(2) dataframe

# %%
#(1) series   it is one dimensional array and it returns only value not column name.

# %%
a = pd.Series([1,45,78,90])
a
# Out:
# 0     1
# 1    45
# 2    78
# 3    90
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
#(2) dataframe  it is miultiple dimensinal array and it return values with column name
#task ::: we have to create a dataframe of employes in which column are
#emp_id,emp_name,department,salary, workinghours

# %%
a={
    "EMP_ID":['A101','A102','A103','A104'],
    "EMP_NAME":["AKKI","lucky","neha","sneha"],
    "DEPARTMENT":["IT","Operation","IT","OPERATION"],
    "SALARY":[15000,25000,30000,45000],
    "WORKING HOURS":[8,9,8,9]
}

# %%
df=pd.DataFrame(a)
df
# Out:
#   EMP_ID EMP_NAME DEPARTMENT  SALARY  WORKING HOURS
# 0   A101     AKKI         IT   15000              8
# 1   A102    lucky  Operation   25000              9
# 2   A103     neha         IT   30000              8
# 3   A104    sneha  OPERATION   45000              9

# %%
#df

# %%
#how we can export our DataFrame into csv data?

# %%
df.to_csv("emp_info.csv")  ###to_csv means export your data into csv file.

# %%
from ast import Index
df.to_csv("new_emp_info.csv",index=False)

# %%
##how to import csv data using pandas

# %%
df=pd.read_csv("/content/emp_info.csv")
df
# Out:
#    Unnamed: 0 EMP_ID EMP_NAME DEPARTMENT  SALARY  WORKING HOURS
# 0           0   A101     AKKI         IT   15000              8
# 1           1   A102    lucky  Operation   25000              9
# 2           2   A103     neha         IT   30000              8
# 3           3   A104    sneha  OPERATION   45000              9

# %%
df=pd.read_csv("/content/new_emp_info.csv")
df
# Out:
#   EMP_ID EMP_NAME DEPARTMENT  SALARY  WORKING HOURS
# 0   A101     AKKI         IT   15000              8
# 1   A102    lucky  Operation   25000              9
# 2   A103     neha         IT   30000              8
# 3   A104    sneha  OPERATION   45000              9

# %%
df=pd.read_csv("/content/classroom.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# 5    84  Female    NaN    Mild  Bangalore       Yes
# 6    14    Male  101.0  Strong  Bangalore        No
# 7    20  Female    NaN  Strong     Mumbai       Yes
# 8    19  Female  100.0  Strong  Bangalore        No
# 9    64  Female  101.0    Mild      Delhi        No
# 10   75  Female    NaN    Mild      Delhi        No
# 11   65  Female   98.0    Mild     Mumbai       Yes
# 12   25  Female   99.0  Strong    Kolkata        No
# 13   64    Male  102.0    Mild  Bangalore       Yes
# 14   51    Male  104.0    Mild  Bangalore        No
# 15   70    Male  103.0  Strong    Kolkata       Yes
# 16   69  Female  103.0    Mild    Kolkata       Yes
# ...

# %%
##### How can we check top 5 data from the dataframe ?
df.head(5)    ### it returns top 5 data by default and if pass value in this it will return that rows.
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
# How can we check bottom data from the dataframe ?
df.tail(2)
# Out:
#     age  gender  fever   cough       city has_covid
# 47   18  Female  104.0    Mild  Bangalore        No
# 48   66    Male   99.0  Strong  Bangalore        No

# %%
### How can we check total columns in this dataframe
df.columns
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
df.sample(3)
# Out:
#     age  gender  fever cough    city has_covid
# 4    65  Female  101.0  Mild  Mumbai        No
# 40   49  Female  102.0  Mild   Delhi        No
# 34   74    Male  102.0  Mild  Mumbai       Yes

# %%
# How can we check datatype of all columns
df.dtypes
# Out:
# age            int64
# gender        object
# fever        float64
# cough         object
# city          object
# has_covid     object
# dtype: object

# %%
# How can we check Statically view of dataframe ?
df.describe()
# Out:
#              age       fever
# count  49.000000   42.000000
# mean   45.836735  100.619048
# std    23.578192    1.912123
# min    12.000000   98.000000
# 25%    23.000000   99.000000
# 50%    42.000000  101.000000
# 75%    66.000000  102.000000
# max    84.000000  104.000000

# %%
# How can we check overall information in the dataframe ?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        49 non-null     int64
#  1   gender     49 non-null     object
#  2   fever      42 non-null     float64
#  3   cough      49 non-null     object
#  4   city       49 non-null     object
#  5   has_covid  49 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 2.4+ KB

# %%
# How can we check missing values in a dataframe ?
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        7
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
# How can we check total sub-categories in a column
df['gender'].value_counts()
# Out:
# gender
# Female    29
# Male      20
# Name: count, dtype: int64

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      33
# Strong    16
# Name: count, dtype: int64

# %%
df['city'].value_counts()
# Out:
# city
# Bangalore    15
# Kolkata      14
# Delhi        13
# Mumbai        7
# Name: count, dtype: int64

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     28
# Yes    21
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].map({"Male":0 , "Female":1})

# %%
df['cough']=df['cough'].map({"Mild":0 , "Strong":1})

# %%
df['city']=df['city'].map({"Kolkata":0 , "Bangalore":1 , "Delhi":2 , "Mumbai":3})

# %%
df['has_covid']=df['has_covid'].map({"No":0 , "Yes":1})

# %%
df.head(5)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       0  103.0      0     0          0
# 1   27       0  100.0      0     2          1
# 2   42       0  101.0      0     2          0
# 3   31       1   98.0      0     0          0
# 4   65       1  101.0      0     3          0

# %%
# Data --->
# Categorical(Descrete) ---> We cannot divide furthur . Ex. has_covid(y,n), marital_status(y,n),result(p,f),
# students_in_class(50,51)
# Numerical(Continuous) ---> We can divide furthur . Ex. distance jaipur to delhi(310.60km), weight(kg,gm),
# salary(rupees), Insurance_charges(rupees) , birth_year(25)

# %%
#df.head
#df.tail

# %%
df.describe()
# Out:
#              age     gender       fever      cough       city  has_covid
# count  49.000000  49.000000   42.000000  49.000000  49.000000  49.000000
# mean   45.836735   0.591837  100.619048   0.326531   1.265306   0.428571
# std    23.578192   0.496587    1.912123   0.473804   1.036330   0.500000
# min    12.000000   0.000000   98.000000   0.000000   0.000000   0.000000
# 25%    23.000000   0.000000   99.000000   0.000000   0.000000   0.000000
# 50%    42.000000   1.000000  101.000000   0.000000   1.000000   0.000000
# 75%    66.000000   1.000000  102.000000   1.000000   2.000000   1.000000
# max    84.000000   1.000000  104.000000   1.000000   3.000000   1.000000

# %%
df['fever']=df['fever'].fillna(df['fever'].mean())

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
#loc() and Iloc()
#df.loc()[row_range,column_name]   start value include and last value include
##df.Iloc()[row_range,column_range]   start value include but last value exclude

# %%
df.loc[5:10,['age','fever','cough']]
# Out:
#     age       fever  cough
# 5    84  100.619048      0
# 6    14  101.000000      1
# 7    20  100.619048      1
# 8    19  100.000000      1
# 9    64  101.000000      0
# 10   75  100.619048      0

# %%
df.iloc[5:10,[0,2]]=55

# %%
#df.head(11)

# %%
df['gender'].value_counts()
# Out:
# gender
# 1    29
# 0    20
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       0  103.0      0     0          0
# 1   27       0  100.0      0     2          1

# %%
df['gender']=df['gender'].map({"Male":0 , "Female":1})
df['cough']=df['cough'].map({"Mild":0 , "Strong":1})

# %%
df['has_covid']=df['has_covid'].map({"Yes":1 , "NO":0})

# %%
#df.sample(3)

# %%
df.drop(columns=['city'])
# Out:
#     age  gender       fever  cough  has_covid
# 0    60     NaN  103.000000    NaN        NaN
# 1    27     NaN  100.000000    NaN        NaN
# 2    42     NaN  101.000000    NaN        NaN
# 3    31     NaN   98.000000    NaN        NaN
# 4    65     NaN  101.000000    NaN        NaN
# 5    55     NaN   55.000000    NaN        NaN
# 6    55     NaN   55.000000    NaN        NaN
# 7    55     NaN   55.000000    NaN        NaN
# 8    55     NaN   55.000000    NaN        NaN
# 9    55     NaN   55.000000    NaN        NaN
# 10   75     NaN  100.619048    NaN        NaN
# 11   65     NaN   98.000000    NaN        NaN
# 12   25     NaN   99.000000    NaN        NaN
# 13   64     NaN  102.000000    NaN        NaN
# 14   51     NaN  104.000000    NaN        NaN
# 15   70     NaN  103.000000    NaN        NaN
# 16   69     NaN  103.000000    NaN        NaN
# 17   40     NaN   98.000000    NaN        NaN
# 18   64     NaN   98.000000    NaN        NaN
# ...

# %%
df=df.drop(columns=['city'])  #how to drop or delete one or more columns

# %%
df.head(2)
# Out:
#    age  gender  fever  cough  has_covid
# 0   60     NaN  103.0    NaN        NaN
# 1   27     NaN  100.0    NaN        NaN

# %%
df.sort_index()   #sort the data
# Out:
#     age  gender       fever  cough  has_covid
# 0    60     NaN  103.000000    NaN        NaN
# 1    27     NaN  100.000000    NaN        NaN
# 2    42     NaN  101.000000    NaN        NaN
# 3    31     NaN   98.000000    NaN        NaN
# 4    65     NaN  101.000000    NaN        NaN
# 5    55     NaN   55.000000    NaN        NaN
# 6    55     NaN   55.000000    NaN        NaN
# 7    55     NaN   55.000000    NaN        NaN
# 8    55     NaN   55.000000    NaN        NaN
# 9    55     NaN   55.000000    NaN        NaN
# 10   75     NaN  100.619048    NaN        NaN
# 11   65     NaN   98.000000    NaN        NaN
# 12   25     NaN   99.000000    NaN        NaN
# 13   64     NaN  102.000000    NaN        NaN
# 14   51     NaN  104.000000    NaN        NaN
# 15   70     NaN  103.000000    NaN        NaN
# 16   69     NaN  103.000000    NaN        NaN
# 17   40     NaN   98.000000    NaN        NaN
# 18   64     NaN   98.000000    NaN        NaN
# ...

# %%
df=df.rename(columns={"cough":"updated_cough"})
df.head(3)
# Out:
#    age  gender  fever  updated_cough  has_covid
# 0   60     NaN  103.0            NaN        NaN
# 1   27     NaN  100.0            NaN        NaN
# 2   42     NaN  101.0            NaN        NaN

# %%
df.iloc[2:5,0:4:2]
# Out:
#    age  fever
# 2   42  101.0
# 3   31   98.0
# 4   65  101.0

# %%
df['Age']=df['age'].add(10)
df.head(3)
# Out:
#    age  gender  fever  updated_cough  has_covid  Age
# 0   60     NaN  103.0            NaN        NaN   70
# 1   27     NaN  100.0            NaN        NaN   37
# 2   42     NaN  101.0            NaN        NaN   52

# %%
df['fever']=df['fever'].sub(100)
df.head(3)
# Out:
#    age  gender  fever  updated_cough  has_covid  Age
# 0   60     NaN    3.0            NaN        NaN   70
# 1   27     NaN    0.0            NaN        NaN   37
# 2   42     NaN    1.0            NaN        NaN   52

# %%
df=df.drop(columns=['Age'])
df.head(3)
# Out:
#    age  gender  fever  updated_cough  has_covid
# 0   60     NaN    3.0            NaN        NaN
# 1   27     NaN    0.0            NaN        NaN
# 2   42     NaN    1.0            NaN        NaN

# %%
df[['fever','age']]  ##using this method ,we can filter the data
# Out:
#         fever  age
# 0    3.000000   60
# 1    0.000000   27
# 2    1.000000   42
# 3   -2.000000   31
# 4    1.000000   65
# 5  -45.000000   55
# 6  -45.000000   55
# 7  -45.000000   55
# 8  -45.000000   55
# 9  -45.000000   55
# 10   0.619048   75
# 11  -2.000000   65
# 12  -1.000000   25
# 13   2.000000   64
# 14   4.000000   51
# 15   3.000000   70
# 16   3.000000   69
# 17  -2.000000   40
# 18  -2.000000   64
# 19   0.619048   42
# 20  -2.000000   12
# 21  -2.000000   73
# 22  -2.000000   71
# 23  -2.000000   80
# 24   0.000000   13
# 25   0.619048   23
# 26   0.000000   19
# 27   2.000000   33
# 28   4.000000   16
# 29   0.619048   34
# 30   1.000000   15
# 31   3.000000   83
# 32   1.000000   34
# 33  -2.000000   26
# 34   2.000000   74
# 35   2.000000   82
# 36   1.000000   38
# 37   0.000000   55
# 38   1.000000   49
# 39   3.000000   50
# 40   2.000000   49
# 41   0.619048   82
# 42   0.000000   27
# 43  -1.000000   22
# 44   2.000000   20
# 45  -1.000000   72
# ...

# %%
df[['age','fever']]
# Out:
#     age      fever
# 0    60   3.000000
# 1    27   0.000000
# 2    42   1.000000
# 3    31  -2.000000
# 4    65   1.000000
# 5    55 -45.000000
# 6    55 -45.000000
# 7    55 -45.000000
# 8    55 -45.000000
# 9    55 -45.000000
# 10   75   0.619048
# 11   65  -2.000000
# 12   25  -1.000000
# 13   64   2.000000
# 14   51   4.000000
# 15   70   3.000000
# 16   69   3.000000
# 17   40  -2.000000
# 18   64  -2.000000
# 19   42   0.619048
# 20   12  -2.000000
# 21   73  -2.000000
# 22   71  -2.000000
# 23   80  -2.000000
# 24   13   0.000000
# 25   23   0.619048
# 26   19   0.000000
# 27   33   2.000000
# 28   16   4.000000
# 29   34   0.619048
# 30   15   1.000000
# 31   83   3.000000
# 32   34   1.000000
# 33   26  -2.000000
# 34   74   2.000000
# 35   82   2.000000
# 36   38   1.000000
# 37   55   0.000000
# 38   49   1.000000
# 39   50   3.000000
# 40   49   2.000000
# 41   82   0.619048
# 42   27   0.000000
# 43   22  -1.000000
# 44   20   2.000000
# 45   72  -1.000000
# ...

# %%
#df.fillna(2)
# Out:
#     age  gender      fever  cough  has_covid
# 0    60     2.0   3.000000    2.0        2.0
# 1    27     2.0   0.000000    2.0        2.0
# 2    42     2.0   1.000000    2.0        2.0
# 3    31     2.0  -2.000000    2.0        2.0
# 4    65     2.0   1.000000    2.0        2.0
# 5    55     2.0 -45.000000    2.0        2.0
# 6    55     2.0 -45.000000    2.0        2.0
# 7    55     2.0 -45.000000    2.0        2.0
# 8    55     2.0 -45.000000    2.0        2.0
# 9    55     2.0 -45.000000    2.0        2.0
# 10   75     2.0   0.619048    2.0        2.0
# 11   65     2.0  -2.000000    2.0        2.0
# 12   25     2.0  -1.000000    2.0        2.0
# 13   64     2.0   2.000000    2.0        2.0
# 14   51     2.0   4.000000    2.0        2.0
# 15   70     2.0   3.000000    2.0        2.0
# 16   69     2.0   3.000000    2.0        2.0
# 17   40     2.0  -2.000000    2.0        2.0
# 18   64     2.0  -2.000000    2.0        2.0
# 19   42     2.0   0.619048    2.0        2.0
# ...

# %%
df=pd.read_csv("/content/placement - placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head(2)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0

# %%
df.tail(2)
# Out:
#     cgpa  resume_score  placed
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample(2)
# Out:
#     cgpa  resume_score  placed
# 22  6.16          5.77       0
# 11  5.44          6.54       0

# %%
df.describe()   #statically view of data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.loc[3:10,['cgpa']]
# Out:
#     cgpa
# 3   6.88
# 4   7.52
# 5   8.77
# 6   5.34
# 7   6.56
# 8   6.32
# 9   7.69
# 10  6.18

# %%
df.iloc[:2,:1]
# Out:
#    cgpa
# 0  8.14
# 1  6.17

# %%
df.isnull().sum()  #for check missing values.
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
b=df.axes
b
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
b=df.dtypes
b
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b=df.empty   #it retunrs true if there any missing data in data frames otherwise
b            #false.
# Out:
# False

# %%
df=df.dropna()  #for remove missing row

# %%
i=df.ndim  #number of axes(it is 2)
i
# Out:
# 2

# %%
t=df.shape    #shape=n(rows),2(columns)
t
# Out:
# (100, 3)

# %%
df.shape[0]  # total rows in data
df.shape[1]  # total column in data
# Out:
# 3

# %%
d=df.size   #row count*column count
d
# Out:
# 300

# %%
a=df.values  #get a numpy array for it.
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df=df.copy()

# %%
p=df.sort_values(by='resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
r=df.sort_index()
r
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
#x=df.astype(int)  type conversion
df['cgpa']=df['cgpa'].astype(int)

# %%
df.head(3)
# Out:
#    cgpa  resume_score  placed
# 0     8          6.52       1
# 1     6          5.17       0
# 2     8          8.86       1

# %%
df['cgpa']=df['cgpa'].astype(str)

# %%
df.dtypes
# Out:
# cgpa             object
# resume_score    float64
# placed            int64
# dtype: object

# %%
df['resume_score']=df['resume_score'].astype(int)

# %%
df.dtypes
# Out:
# cgpa            object
# resume_score     int64
# placed           int64
# dtype: object

# %%
t
df['resume_score']=df['resume_score'].add(4)

# %%
df.head(2)
# Out:
#   cgpa  resume_score  placed
# 0    8            10       1
# 1    6             9       0

# %%
s=df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p=df.max()
p
# Out:
# cgpa             9
# resume_score    13
# placed           1
# dtype: object

# %%
q=df.min()
q
# Out:
# cgpa            5
# resume_score    8
# placed          0
# dtype: object

# %%
g=df.filter(items=['cgpa','placed'])
g
# Out:
#    cgpa  placed
# 0     8       1
# 1     6       0
# 2     8       1
# 3     6       1
# 4     7       1
# ..  ...     ...
# 95    6       0
# 96    8       1
# 97    6       0
# 98    8       1
# 99    6       0
#
# [100 rows x 2 columns]

# %%
df[['cgpa','placed']]   # second option of filtering
# Out:
#    cgpa  placed
# 0     8       1
# 1     6       0
# 2     8       1
# 3     6       1
# 4     7       1
# ..  ...     ...
# 95    6       0
# 96    8       1
# 97    6       0
# 98    8       1
# 99    6       0
#
# [100 rows x 2 columns]

# %%
s=df.filter(items=[5,6],axis=0)  #axis=0 0 means rowswise operation
s
# Out:
#   cgpa  resume_score  placed
# 5    8            10       1
# 6    5            11       0

# %%
t=df.filter(like='5',axis=0)
t
# Out:
#    cgpa  resume_score  placed
# 5     8            10       1
# 15    8             9       1
# 25    7             9       1
# 35    8            11       1
# 45    8             9       1
# 50    8            10       1
# 51    6            11       0
# 52    5            11       0
# 53    6            11       0
# 54    5            11       0
# 55    6            10       1
# 56    6            10       0
# 57    6            11       0
# 58    6            11       0
# 59    5            11       0
# 65    6            12       0
# 75    6            11       1
# 85    6             9       0
# 95    6            10       0

# %%
#a=df.to_csv("path location")
#b=df.to_dict()---->save in dictionary
#c=df.to_str()--->save in string

# %%
p=df.rename(columns={'cgpa':'updated_cgpa','resume_score':'semester marks'})
p    #how to rename a column
# Out:
#    updated_cgpa  semester marks  placed
# 0             8              10       1
# 1             6               9       0
# 2             8              12       1
# 3             6              11       1
# 4             7              11       1
# ..          ...             ...     ...
# 95            6              10       0
# 96            8              11       1
# 97            6              11       0
# 98            8               9       1
# 99            6              10       0
#
# [100 rows x 3 columns]

# %%
df['cgpa']=df['cgpa'].astype(int)

# %%
df['half']=df['cgpa'].where(df['cgpa']>7,other=0)
df.head(10)
# Out:
#    cgpa  resume_score  placed  half
# 0     8            10       1     8
# 1     6             9       0     0
# 2     8            12       1     8
# 3     6            11       1     0
# 4     7            11       1     0
# 5     8            10       1     8
# 6     5            11       0     0
# 7     6            10       0     0
# 8     6            10       0     0
# 9     7            11       1     0

# %%
df.groupby('placed').size()
# Out:
# placed
# 0    50
# 1    50
# dtype: int64
