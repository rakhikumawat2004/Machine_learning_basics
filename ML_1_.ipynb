# %%
#normal distribution
#from central tendency (mean mode median)  left to right side equal data points
#identification
# mean=0 standard deviation =1

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/covid_toy - covid_toy.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df=df.dropna()

# %%
df=df.drop(columns=['city','cough'])

# %%
df.head(3)
# Out:
#    age gender  fever has_covid
# 0   60   Male  103.0        No
# 1   27   Male  100.0       Yes
# 2   42   Male  101.0        No

# %%
df['gender']=df['gender'].map({"male":0,"female":1})
df['has_covid']=df['has_covid'].map({"No":0,"Yes":1})

# %%
df.head(5)
# Out:
#    age  gender  fever  has_covid
# 0   60     NaN  103.0          0
# 1   27     NaN  100.0          1
# 2   42     NaN  101.0          0
# 3   31     NaN   98.0          0
# 4   65     NaN  101.0          0

# %%
x=df.drop(columns=['has_covid'])
y=df['has_covid']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,y_train,x_test,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
np.round(x_train.describe(),2)
# Out:
#          age  gender   fever
# count  72.00     0.0   72.00
# mean   43.53     NaN  100.74
# std    25.30     NaN    2.12
# min     5.00     NaN   98.00
# 25%    19.75     NaN   99.00
# 50%    47.00     NaN  101.00
# 75%    65.25     NaN  102.25
# max    83.00     NaN  104.00

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

# %%
x_train_sc=sc.fit_transform(x_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/extmath.py:1101: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/extmath.py:1106: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/extmath.py:1126: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %%
x_train_new=pd.DataFrame(x_train_sc,columns=x_train.columns)

# %%
np.round(x_train_new.describe(),2)
# Out:
#          age  gender  fever
# count  72.00     0.0  72.00
# mean   -0.00     NaN  -0.00
# std     1.01     NaN   1.01
# min    -1.53     NaN  -1.30
# 25%    -0.95     NaN  -0.83
# 50%     0.14     NaN   0.13
# 75%     0.86     NaN   0.72
# max     1.57     NaN   1.55

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips['sex']=tips['sex'].map({"male":0,"female":1})
tips['smoker']=tips['smoker'].map({"No":0,"Yes":1})
tips['day'] = tips['day'].map({"Thur":0, "Fri":1, "Sat":2, "Sun":3})
tips['time'] = tips['time'].map({"Lunch":0, "Dinner":1})

# %%
x=tips.drop(columns=['total_bill'])
y=tips['total_bill']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
np.round(x_train.describe(),2)
# Out:
#           tip  sex  smoker    size
# count  195.00  0.0     0.0  195.00
# mean     3.09  NaN     NaN    2.57
# std      1.43  NaN     NaN    0.94
# min      1.00  NaN     NaN    1.00
# 25%      2.00  NaN     NaN    2.00
# 50%      3.00  NaN     NaN    2.00
# 75%      3.70  NaN     NaN    3.00
# max     10.00  NaN     NaN    6.00

# %%
x_train_sc=sc.fit_transform(x_train) #fit means learn the parameters
#transform means apply on that data
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/extmath.py:1101: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/extmath.py:1106: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/extmath.py:1126: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %%
x_train_new=pd.DataFrame(x_train_sc,columns=x_train.columns)

# %%
np.round(x_train_new.describe(),2)
# Out:
#           tip  sex  smoker     day    time    size
# count  195.00  0.0     0.0  195.00  195.00  195.00
# mean    -0.00  NaN     NaN    0.00    0.00   -0.00
# std      1.00  NaN     NaN    1.00    1.00    1.00
# min     -1.46  NaN     NaN   -1.53   -1.64   -1.68
# 25%     -0.76  NaN     NaN   -0.65   -1.64   -0.61
# 50%     -0.06  NaN     NaN    0.23    0.61   -0.61
# 75%      0.43  NaN     NaN    1.10    0.61    0.45
# max      4.85  NaN     NaN    1.10    0.61    3.65
